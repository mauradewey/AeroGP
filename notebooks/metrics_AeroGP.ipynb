# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib
import seaborn as sns
import cartopy.crs as ccrs
import glob
from xskillscore import crps_gaussian
from scipy.stats import ttest_ind_from_stats as ttest
import pandas as pd
import os
import dataframe_image as dfi

# %%
#some utils:

def area_grid(lat, lon):
    """
    Calculate the area of each grid cell
    Area is in square meters
    -----------
    modified from
    https://towardsdatascience.com/the-correct-way-to-average-the-globe-92ceecd172b7
    Based on the function in
    https://github.com/chadagreene/CDT/blob/master/cdt/cdtarea.m
    """
    from numpy import meshgrid, deg2rad, gradient, cos
    from xarray import DataArray

    xlon, ylat = meshgrid(lon, lat)
    R = earth_radius(ylat)

    dlat = deg2rad(gradient(ylat, axis=0))
    dlon = deg2rad(gradient(xlon, axis=1))

    dy = dlat * R
    dx = dlon * R * cos(deg2rad(ylat))

    area = dy * dx

    xda = DataArray(
        area,
        dims=["lat", "lon"],
        coords={"lat": lat, "lon": lon},
        attrs={
            "long_name": "area_per_pixel",
            "description": "area per pixel",
            "units": "m^2",
        },
    )
    return xda

def earth_radius(lat):
    '''
    -----------
    Copied from
    https://towardsdatascience.com/the-correct-way-to-average-the-globe-92ceecd172b7
    WGS84: https://earth-info.nga.mil/GandG/publications/tr8350.2/tr8350.2-a/Chapter%203.pdf
    '''
    from numpy import deg2rad, sin, cos

    # define oblate spheroid from WGS84
    a = 6378137
    b = 6356752.3142
    e2 = 1 - (b**2/a**2)
    
    # convert from geodecic to geocentric
    # see equation 3-110 in WGS84
    lat = deg2rad(lat)
    lat_gc = np.arctan( (1-e2)*np.tan(lat) )

    # radius equation
    # see equation 3-107 in WGS84
    r = (
        (a * (1 - e2)**0.5) 
         / (1 - (e2 * np.cos(lat_gc)**2))**0.5 
        )

    return r


def lat_weighted_mean(x):
    weights = np.cos(np.deg2rad(x.lat))
    return x.weighted(weights).mean(['lat', 'lon'])

def lat_weighted_sum(x):
    weights = np.cos(np.deg2rad(x.lat))
    return x.weighted(weights).sum(['lat', 'lon'])

def normalize_data(data):
    #normalize data by mean and std
    mean = data.mean()
    std = data.std()
    data = (data - mean) / std
    return data, mean, std

#std NRMSE:
def get_std_nrmse(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return np.sqrt(((truth - pred)**2).weighted(weights).mean(['lat', 'lon'])).data / truth.weighted(weights).std().data

#NRMSE:
def get_nrmse(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return np.sqrt(((truth - pred)**2).weighted(weights).mean(['lat', 'lon'])).data / np.abs(truth.weighted(weights).mean(['lat','lon']).data)

#mean bias:
def get_bias(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return (pred - truth).weighted(weights).mean(['lat', 'lon']).data

#crps:
def get_crps(truth, pred, std):
    weights = np.cos(np.deg2rad(truth.lat))
    crps = crps_gaussian(truth, pred, std, weights=weights)
    if isinstance(crps, xr.DataArray):
        return crps
    else:
        return crps.to_array()
    
#ece:
def regression_ece(y_true, y_mean, y_std, coverages=np.linspace(0.1, 0.9, 9)):
    ece = 0.0
    for c in coverages:
        # z-score for the central predictive interval
        z = abs(np.percentile(np.random.normal(0, 1, 10_000), (1 + c) / 2 * 100))
        lower = y_mean - z * y_std
        upper = y_mean + z * y_std
        
        empirical_cov = np.mean((y_true >= lower) & (y_true <= upper))
        ece += abs(empirical_cov - c)
    
    return ece / len(coverages)



def get_ence(y_true, y_mean, y_std, num_bins=10, eps=1e-8):
    """
    ENCE per Levi et al., with division by RMV(j) and safe handling of empty bins / tiny RMV.
    
    Parameters
    ----------
    y_true : array-like, shape (T,)
        Observed values.
    y_mean : array-like, shape (T,)
        Predicted means.
    y_std : array-like, shape (T,)
        Predicted standard deviations (sigma_t >= 0).
    num_bins : int
        Number of bins to partition predictions by predicted std (RMV).
    eps : float
        Small value to avoid division by zero for near-zero RMV.
    
    Returns
    -------
    ence_value : float
        ENCE computed as 1/N * sum_j |RMV(j)-RMSE(j)| / RMV(j).
    details : dict
        Optional diagnostics: arrays of rmv, rmse, counts, bin_edges.
    """
    y_true = np.asarray(y_true)
    y_mean = np.asarray(y_mean)
    y_std = np.asarray(y_std)

    # Bin by predicted std
    bin_edges = np.linspace(y_std.min(), y_std.max(), num_bins + 1)
    rmv_list = []
    rmse_list = []
    counts = []

    for i in range(num_bins):
        mask = (y_std >= bin_edges[i]) & (y_std < bin_edges[i+1])
        # include rightmost edge in last bin
        if i == num_bins - 1:
            mask = (y_std >= bin_edges[i]) & (y_std <= bin_edges[i+1])

        cnt = np.count_nonzero(mask)
        counts.append(cnt)

        if cnt == 0:
            # For empty bins we can either skip or set rmv/rmse to nan.
            rmv_list.append(np.nan)
            rmse_list.append(np.nan)
            continue

        rmv = np.sqrt(np.mean(y_std[mask]**2))
        rmse = np.sqrt(np.mean((y_true[mask] - y_mean[mask])**2))
        rmv_list.append(rmv)
        rmse_list.append(rmse)

    rmv_arr = np.array(rmv_list)
    rmse_arr = np.array(rmse_list)
    counts = np.array(counts)

    # Only consider non-empty bins for the average; follow Levi by dividing by N (number of bins),
    # but typical robust option: average only over non-empty bins. We offer both.
    valid = ~np.isnan(rmv_arr)

    # safe RMV for division
    rmv_safe = np.where(valid, np.maximum(rmv_arr, eps), np.nan)

    per_bin_relative_err = np.abs(rmv_arr - rmse_arr) / rmv_safe  # nan preserved for empty bins

    # Option A (Levi): average over ALL bins (treat empty bins as 0 contribution or skip?)
    # Levi uses 1/N sum; if bins are empty, it's ambiguous. We compute average over non-empty by default.
    ence_value = np.nanmean(per_bin_relative_err)  # averages over non-empty by default

    details = {
        'rmv': rmv_arr,
        'rmse': rmse_arr,
        'counts': counts,
        'bin_edges': bin_edges,
        'per_bin_relative_err': per_bin_relative_err
    }
    return ence_value

# %%
# create pandas dataframe of stats for Figure 2.
# Columns are:
# 0. experiment name
# 1. % of area of siginificant response in NorESM experiment (p_val<0.05 for last 10 years of transient experiments, p_val<0.05 for equilibrium experiments)
# 2. NRMSE for NorESM and AeroGP
# 3. CRPS for NorESM and AeroGP
# 4. Mean Bias

s =[]

for ii in glob.glob('../NorESM_stat_data/stats_fdc*.nc'):
    stats = xr.open_dataset(ii)

    pval = stats.fdr_adjusted_p_values

    #experiment name:
    exp = stats.attrs['experiment_id']

    #for equilibrium experiments p-values are 2D:
    if pval.ndim == 2:
        pval_area = (area_grid(stats.lat, stats.lon).where(pval<0.05)).sum()

    #for transient experiments p-values are 3D, we use last 20 years (first window):
    if pval.ndim == 3:
        pval_area = (area_grid(stats.lat, stats.lon).where(pval[0]<0.05)).sum()
    
    #percentage of significant area (where p<0.05):
    total_area = area_grid(stats.lat, stats.lon).sum()
    significant_area = (pval_area.values/total_area.values)*100

    #append to list:
    s.append(
        {
            'Experiment': exp,
            'NorESM mean sig. area (%)': significant_area,
    
        }
    )



#calculate NRMSE, CRPS and Bias for each experiment:
s2 = []

for ii in glob.glob('../training_data_v2/outputs*.nc'):
    
    #get NorESM target data:
    NorESM_out = xr.open_dataset(ii)
    exp_id = NorESM_out.attrs['experiment_id']
    print(ii)

    if exp_id == 'RAMIP T1: ssp126-ssp370':
        exp_id = 'RAMIP T1'

    #get corresponding AeroGP posterior:
    list_of_files = glob.glob('../logs/lr_v2/' + exp_id + '/posterior_predictY_*.nc') 
    #list_of_files = glob.glob('../logs/logs_' + exp_id + '/posterior_predictY_*.nc')
    latest_file = max(list_of_files, key=os.path.getctime)
    AeroGP_out = xr.open_dataset(latest_file)
    print(latest_file)
    
    #for transient experiments use mean of last 20 years:
    if exp_id == 'ssp245-aer': # use first 20 years:
        NorESM_out_mean = NorESM_out['tas_diff'].isel(year=slice(0,20)).mean('year')
        AeroGP_out_mean = AeroGP_out['posterior'].isel(year=slice(0,20)).mean('year')
        AeroGP_out_std = np.sqrt(np.power(AeroGP_out['posterior std'].isel(year=slice(0,20)),2).mean('year'))
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

        crps = get_crps(NorESM_out_mean, AeroGP_out_mean, AeroGP_out_std)

    elif NorESM_out.tas_diff.ndim == 3:
        NorESM_out_mean = NorESM_out['tas_diff'].isel(year=slice(-20,None)).mean('year')
        AeroGP_out_mean = AeroGP_out['posterior'].isel(year=slice(-20,None)).mean('year')
        AeroGP_out_std = np.sqrt(np.power(AeroGP_out['posterior std'].isel(year=slice(-20,None)),2).mean('year'))
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

        NorESM_ensemble = xr.open_dataset('../ensemble_data/'+ ii.split('\\')[1].split('.')[0] + '_ensemble.nc')
        crps = get_crps(NorESM_ensemble.isel(year=slice(-20,None)), AeroGP_out['posterior'].isel(year=slice(-20,None)), AeroGP_out['posterior std'].isel(year=slice(-20,None)))

    elif NorESM_out.tas_diff.ndim == 2:
        NorESM_out_mean = NorESM_out['tas_diff']
        AeroGP_out_mean = AeroGP_out['posterior']
        AeroGP_out_std = AeroGP_out['posterior std']
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

        NorESM_ensemble = xr.open_dataset('../ensemble_data/'+ ii.split('\\')[1].split('.')[0] + '_ensemble.nc')
        crps = get_crps(NorESM_ensemble, AeroGP_out['posterior'], AeroGP_out['posterior std'])

    #calculate metrics:
    nrmse = get_nrmse(NorESM_out_mean, AeroGP_out_mean)
    std_nrmse = get_std_nrmse(NorESM_out_mean, AeroGP_out_mean)
    bias = get_bias(NorESM_out_mean, AeroGP_out_mean)
    ence = get_ence(NorESM_out_mean, AeroGP_out_mean, AeroGP_out_std)
    ece = regression_ece(NorESM_out_mean, AeroGP_out_mean, AeroGP_out_std)


    #append to list:
    s2.append(
        {
            'Experiment': exp_id,
            'NRMSE': std_nrmse,
            'ECE' : ece,
            'CRPS': crps,
            'Mean Bias': bias,
            r'ΔT' + ' NorESM (K)': NorESM_glb_mean,
            r'ΔT' + ' AeroGP (K)': AeroGP_glb_mean,
        }
    )

#merge the two lists:
df1 = pd.DataFrame(s)
df2 = pd.DataFrame(s2)
df = pd.merge(df1, df2, on='Experiment')
# Out:
# ../training_data_v2\outputs_0xEA_SO2.nc
# ../logs/lr_v2/0xEA SO2 only\posterior_predictY_0xEA_SO2_20250806-192634.nc
# ../training_data_v2\outputs_0xEU_SO2.nc
# ../logs/lr_v2/0xEU SO2 only\posterior_predictY_0xEU_SO2_20250806-202944.nc
# ../training_data_v2\outputs_0xNA_SO2.nc
# ../logs/lr_v2/0xNA SO2 only\posterior_predictY_0xNA_SO2_20250806-234301.nc
# ../training_data_v2\outputs_0xSA_SO2.nc
# ../logs/lr_v2/0xSA SO2 only\posterior_predictY_0xSA_SO2_20250807-025846.nc
# ../training_data_v2\outputs_10xEU_BC.nc
# ../logs/lr_v2/10xEU BC only\posterior_predictY_10xEU_BC_20250806-205034.nc
# ../training_data_v2\outputs_10xNA_BC.nc
# ../logs/lr_v2/10xNA BC only\posterior_predictY_10xNA_BC_20250807-000452.nc
# ../training_data_v2\outputs_10xSA_BC.nc
# ../logs/lr_v2/10xSA BC only\posterior_predictY_10xSA_BC_20250807-032037.nc
# ../training_data_v2\outputs_10xSA_SO2.nc
# ../logs/lr_v2/10xSA SO2 only\posterior_predictY_10xSA_SO2_20250807-034158.nc
# ../training_data_v2\outputs_5xEA_BC.nc
# ../logs/lr_v2/5xEA BC only\posterior_predictY_5xEA_BC_20250806-194737.nc
# ../training_data_v2\outputs_5xEA_SO2.nc
# ../logs/lr_v2/5xEA SO2 only\posterior_predictY_5xEA_SO2_20250806-200833.nc
# ../training_data_v2\outputs_5xNA_SO2.nc
# ../logs/lr_v2/5xNA SO2 only\posterior_predictY_5xNA_SO2_20250807-002737.nc
# ../training_data_v2\outputs_7xEU_SO2.nc
# ../logs/lr_v2/7xEU SO2 only\posterior_predictY_eu_SO2x2_20250823-121343.nc
# ../training_data_v2\outputs_AeroGP1.nc
# ../logs/lr_v2/AeroGP1\posterior_predictY_AeroGP1_20250806-184508.nc
# ../training_data_v2\outputs_AeroGP2.nc
# ../logs/lr_v2/AeroGP2\posterior_predictY_AeroGP2_20250806-190532.nc
# ../training_data_v2\outputs_global_anthro.nc
# ../logs/lr_v2/Global Anthro Removal\posterior_predictY_global_anthro_20250806-213336.nc
# ../training_data_v2\outputs_global_BC.nc
# ../logs/lr_v2/Global BC removal only\posterior_predictY_global_BC_20250806-215506.nc
# ../training_data_v2\outputs_global_OC.nc
# ../logs/lr_v2/Global OC removal only\posterior_predictY_global_OC_20250806-221712.nc
# ../training_data_v2\outputs_global_SO2.nc
# ../logs/lr_v2/Global SO2 removal only\posterior_predictY_global_SO2_20250806-223832.nc
# ../training_data_v2\outputs_hist-aer.nc
# ../logs/lr_v2/hist-aer\posterior_predictY_hist-aer_20250806-230000.nc
# ../training_data_v2\outputs_ramip_af.nc
# ../logs/lr_v2/RAMIP AF\posterior_predictY_ramip_af_20250807-004917.nc
# ../training_data_v2\outputs_ramip_ea.nc
# ../logs/lr_v2/RAMIP EA\posterior_predictY_ramip_ea_20250807-011057.nc
# ../training_data_v2\outputs_ramip_nae.nc
# ../logs/lr_v2/RAMIP NAE\posterior_predictY_ramip_nae_20250807-013228.nc
# ../training_data_v2\outputs_ramip_sa.nc
# ../logs/lr_v2/RAMIP SA\posterior_predictY_ramip_sa_20250807-015402.nc
# ../training_data_v2\outputs_ramip_t1.nc
# ../logs/lr_v2/RAMIP T1\posterior_predictY_ramip_t1_20250807-021535.nc
# ../training_data_v2\outputs_ssp245-aer.nc
# ../logs/lr_v2/ssp245-aer\posterior_predictY_ssp245-aer_20250807-040320.nc
# ../training_data_v2\outputs_ssp370-NTCF.nc
# ../logs/lr_v2/ssp370-lowNTCF\posterior_predictY_ssp370-NTCF_20250807-042453.nc

# %%
# some edits for display

#fix some experiment names for plotting table:
df.replace('ssp245-aer', 'DAMIP ssp245-aer', inplace=True)
df.replace('hist-aer', 'DAMIP hist-aer', inplace=True)
df.replace('RAMIP T1', 'RAMIP ssp370-126aer', inplace=True)
df.replace('RAMIP EA', 'RAMIP EAS', inplace=True)
df.replace('RAMIP SA', 'RAMIP SAS', inplace=True)
df.replace('RAMIP AF', 'RAMIP AFR', inplace=True)


df = df.infer_objects().astype(np.float64, errors='ignore')

#add column for NorESM version:
df['NorESM version'] = np.where(df['Experiment'].str.contains('RAMIP') | df['Experiment'].str.contains('DAMIP') | df['Experiment'].str.contains('AeroGP') | df['Experiment'].str.contains('ssp370'), 'NorESM2', 'NorESM1')

# %%
df.sort_values(by='NRMSE').style\
    .background_gradient()\
    .format(precision=2)\
    .hide()
# Out:
# <style type="text/css">
# #T_58cad_row0_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_58cad_row0_col2, #T_58cad_row1_col4, #T_58cad_row2_col3, #T_58cad_row2_col6, #T_58cad_row2_col7, #T_58cad_row18_col5, #T_58cad_row23_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_58cad_row0_col3 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_58cad_row0_col4, #T_58cad_row6_col6, #T_58cad_row20_col7, #T_58cad_row23_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_58cad_row0_col5, #T_58cad_row10_col5 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_58cad_row0_col6 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_58cad_row0_col7 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_58cad_row1_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_58cad_row1_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_58cad_row1_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_58cad_row1_col5, #T_58cad_row8_col7 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_58cad_row1_col6, #T_58cad_row8_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_58cad_row1_col7 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_58cad_row2_col1, #T_58cad_row25_col5 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_58cad_row2_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_58cad_row2_col4, #T_58cad_row3_col3, #T_58cad_row4_col1, #T_58cad_row4_col6, #T_58cad_row4_col7, #T_58cad_row22_col5, #T_58cad_row25_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_58cad_row2_col5 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_58cad_row3_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_58cad_row3_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_58cad_row3_col4, #T_58cad_row5_col5, #T_58cad_row23_col4 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_58cad_row3_col5, #T_58cad_row12_col4, #T_58cad_row22_col6, #T_58cad_row24_col4 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_58cad_row3_col6, #T_58cad_row8_col6, #T_58cad_row13_col6, #T_58cad_row24_col3 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_58cad_row3_col7, #T_58cad_row12_col5, #T_58cad_row18_col1, #T_58cad_row19_col3, #T_58cad_row23_col6 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_58cad_row4_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_58cad_row4_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_58cad_row4_col4 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_58cad_row4_col5, #T_58cad_row5_col4 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_58cad_row5_col1, #T_58cad_row5_col6 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_58cad_row5_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_58cad_row5_col3, #T_58cad_row17_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_58cad_row5_col7 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_58cad_row6_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_58cad_row6_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_58cad_row6_col3 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_58cad_row6_col4, #T_58cad_row17_col7, #T_58cad_row20_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_58cad_row6_col5, #T_58cad_row16_col7 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_58cad_row6_col7 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_58cad_row7_col1, #T_58cad_row14_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_58cad_row7_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_58cad_row7_col3 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_58cad_row7_col4 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_58cad_row7_col5, #T_58cad_row21_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_58cad_row7_col6, #T_58cad_row20_col6 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_58cad_row7_col7, #T_58cad_row10_col7, #T_58cad_row21_col5 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_58cad_row8_col1, #T_58cad_row14_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_58cad_row8_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_58cad_row8_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_58cad_row8_col5, #T_58cad_row19_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_58cad_row9_col1, #T_58cad_row19_col5 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_58cad_row9_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_58cad_row9_col3 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_58cad_row9_col4, #T_58cad_row14_col5, #T_58cad_row19_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_58cad_row9_col5 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_58cad_row9_col6, #T_58cad_row21_col4 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_58cad_row9_col7 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_58cad_row10_col1, #T_58cad_row25_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_58cad_row10_col2, #T_58cad_row11_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_58cad_row10_col3 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_58cad_row10_col4, #T_58cad_row11_col4, #T_58cad_row20_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_58cad_row10_col6, #T_58cad_row23_col5 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_58cad_row11_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_58cad_row11_col3, #T_58cad_row18_col7 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_58cad_row11_col5 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_58cad_row11_col6 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_58cad_row11_col7 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_58cad_row12_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_58cad_row12_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_58cad_row12_col3 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_58cad_row12_col6 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_58cad_row12_col7 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_58cad_row13_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_58cad_row13_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_58cad_row13_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_58cad_row13_col4, #T_58cad_row13_col7 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_58cad_row13_col5 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_58cad_row14_col1, #T_58cad_row22_col4 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_58cad_row14_col3 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_58cad_row14_col6, #T_58cad_row16_col3 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_58cad_row14_col7, #T_58cad_row25_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_58cad_row15_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_58cad_row15_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_58cad_row15_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_58cad_row15_col4 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_58cad_row15_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_58cad_row15_col6, #T_58cad_row21_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_58cad_row15_col7, #T_58cad_row25_col7 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_58cad_row16_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_58cad_row16_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_58cad_row16_col4, #T_58cad_row21_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_58cad_row16_col5 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_58cad_row16_col6, #T_58cad_row24_col7 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_58cad_row17_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_58cad_row17_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_58cad_row17_col4 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_58cad_row17_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }

# %%
#save to csv:
df.to_csv('figure2_stats_lr_v2.csv', index=False)
