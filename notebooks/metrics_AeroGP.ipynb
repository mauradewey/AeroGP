# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib
import seaborn as sns
import cartopy.crs as ccrs
import glob
from xskillscore import crps_gaussian
from scipy.stats import ttest_ind_from_stats as ttest
import pandas as pd
import os
import dataframe_image as dfi

# %%
#some utils:

def area_grid(lat, lon):
    """
    Calculate the area of each grid cell
    Area is in square meters
    -----------
    modified from
    https://towardsdatascience.com/the-correct-way-to-average-the-globe-92ceecd172b7
    Based on the function in
    https://github.com/chadagreene/CDT/blob/master/cdt/cdtarea.m
    """
    from numpy import meshgrid, deg2rad, gradient, cos
    from xarray import DataArray

    xlon, ylat = meshgrid(lon, lat)
    R = earth_radius(ylat)

    dlat = deg2rad(gradient(ylat, axis=0))
    dlon = deg2rad(gradient(xlon, axis=1))

    dy = dlat * R
    dx = dlon * R * cos(deg2rad(ylat))

    area = dy * dx

    xda = DataArray(
        area,
        dims=["lat", "lon"],
        coords={"lat": lat, "lon": lon},
        attrs={
            "long_name": "area_per_pixel",
            "description": "area per pixel",
            "units": "m^2",
        },
    )
    return xda

def earth_radius(lat):
    '''
    -----------
    Copied from
    https://towardsdatascience.com/the-correct-way-to-average-the-globe-92ceecd172b7
    WGS84: https://earth-info.nga.mil/GandG/publications/tr8350.2/tr8350.2-a/Chapter%203.pdf
    '''
    from numpy import deg2rad, sin, cos

    # define oblate spheroid from WGS84
    a = 6378137
    b = 6356752.3142
    e2 = 1 - (b**2/a**2)
    
    # convert from geodecic to geocentric
    # see equation 3-110 in WGS84
    lat = deg2rad(lat)
    lat_gc = np.arctan( (1-e2)*np.tan(lat) )

    # radius equation
    # see equation 3-107 in WGS84
    r = (
        (a * (1 - e2)**0.5) 
         / (1 - (e2 * np.cos(lat_gc)**2))**0.5 
        )

    return r


def lat_weighted_mean(x):
    weights = np.cos(np.deg2rad(x.lat))
    return x.weighted(weights).mean(['lat', 'lon'])

def lat_weighted_sum(x):
    weights = np.cos(np.deg2rad(x.lat))
    return x.weighted(weights).sum(['lat', 'lon'])

def normalize_data(data):
    #normalize data by mean and std
    mean = data.mean()
    std = data.std()
    data = (data - mean) / std
    return data, mean, std


#NRMSE:
def get_nrmse(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return np.sqrt(((truth - pred)**2).weighted(weights).mean(['lat', 'lon'])).data / np.abs(truth.weighted(weights).mean(['lat','lon']).data)

#mean bias:
def get_bias(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return (pred - truth).weighted(weights).mean(['lat', 'lon']).data

#crps:
def get_crps(truth, pred, std):
    weights = np.cos(np.deg2rad(truth.lat))
    return crps_gaussian(truth, pred, std, weights=weights).data

# %%
# create pandas dataframe of stats for Figure 2.
# Columns are:
# 0. experiment name
# 1. % of area of siginificant response in NorESM experiment (p_val<0.05 for last 10 years of transient experiments, p_val<0.05 for equilibrium experiments)
# 2. NRMSE for NorESM and AeroGP
# 3. CRPS for NorESM and AeroGP
# 4. Mean Bias

s =[]

for ii in glob.glob('../NorESM_stat_data/stats_fdc*.nc'):
    stats = xr.open_dataset(ii)

    pval = stats.fdr_adjusted_p_values

    #experiment name:
    exp = stats.attrs['experiment_id']

    #for equilibrium experiments p-values are 2D:
    if pval.ndim == 2:
        pval_area = (area_grid(stats.lat, stats.lon).where(pval<0.05)).sum()

    #for transient experiments p-values are 3D, we use last 20 years (first window):
    if pval.ndim == 3:
        pval_area = (area_grid(stats.lat, stats.lon).where(pval[0]<0.05)).sum()
    
    #percentage of significant area (where p<0.05):
    total_area = area_grid(stats.lat, stats.lon).sum()
    significant_area = (pval_area.values/total_area.values)*100

    #append to list:
    s.append(
        {
            'Experiment': exp,
            'NorESM mean sig. area (%)': significant_area,
    
        }
    )



#calculate NRMSE, CRPS and Bias for each experiment:
s2 = []

for ii in glob.glob('../training_data_v2/outputs*.nc'):
    
    #get NorESM target data:
    NorESM_out = xr.open_dataset(ii)
    exp_id = NorESM_out.attrs['experiment_id']
    print(ii)

    if exp_id == 'RAMIP T1: ssp126-ssp370':
        exp_id = 'RAMIP T1'

    #get corresponding AeroGP posterior:
    list_of_files = glob.glob('../logs/lr_1lin/' + exp_id + '/posterior_predictY_*.nc') # * means all if need specific format then *.csv
    #list_of_files = glob.glob('../logs/logs_' + exp_id + '/posterior_predictY_*.nc')
    latest_file = max(list_of_files, key=os.path.getctime)
    AeroGP_out = xr.open_dataset(latest_file)
    print(latest_file)
    
    #for transient experiments use mean of last 20 years:
    if exp_id == 'ssp245-aer': # use first 20 years:
        NorESM_out_mean = NorESM_out['tas_diff'].isel(year=slice(0,20)).mean('year')
        AeroGP_out_mean = AeroGP_out['posterior'].isel(year=slice(0,20)).mean('year')
        AeroGP_out_std = np.sqrt(np.power(AeroGP_out['posterior std'].isel(year=slice(0,20)),2).mean('year'))
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

    elif NorESM_out.tas_diff.ndim == 3:
        NorESM_out_mean = NorESM_out['tas_diff'].isel(year=slice(-20,None)).mean('year')
        AeroGP_out_mean = AeroGP_out['posterior'].isel(year=slice(-20,None)).mean('year')
        AeroGP_out_std = np.sqrt(np.power(AeroGP_out['posterior std'].isel(year=slice(-20,None)),2).mean('year'))
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

    elif NorESM_out.tas_diff.ndim == 2:
        NorESM_out_mean = NorESM_out['tas_diff']
        AeroGP_out_mean = AeroGP_out['posterior']
        AeroGP_out_std = AeroGP_out['posterior std']
        NorESM_glb_mean = lat_weighted_mean(NorESM_out_mean).values
        AeroGP_glb_mean = lat_weighted_mean(AeroGP_out_mean).values

    #calculate NRMSE, CRPS and Bias:
    nrmse = get_nrmse(NorESM_out_mean, AeroGP_out_mean)
    crps = get_crps(NorESM_out_mean, AeroGP_out_mean, AeroGP_out_std)
    bias = get_bias(NorESM_out_mean, AeroGP_out_mean)


    #append to list:
    s2.append(
        {
            'Experiment': exp_id,
            'NRMSE': nrmse,
            'CRPS': crps,
            'Mean Bias': bias,
            r'ΔT' + ' NorESM (K)': NorESM_glb_mean,
            r'ΔT' + ' AeroGP (K)': AeroGP_glb_mean,
        }
    )

#merge the two lists:
df1 = pd.DataFrame(s)
df2 = pd.DataFrame(s2)
df = pd.merge(df1, df2, on='Experiment')
# Out:
# ../training_data_v2\outputs_0xEA_SO2.nc
# ../logs/lr_1lin/0xEA SO2 only\posterior_predictY_0xEA_SO2_20250325-002212.nc
# ../training_data_v2\outputs_0xEU_SO2.nc
# ../logs/lr_1lin/0xEU SO2 only\posterior_predictY_0xEU_SO2_20250325-013028.nc
# ../training_data_v2\outputs_0xNA_SO2.nc
# ../logs/lr_1lin/0xNA SO2 only\posterior_predictY_0xNA_SO2_20250325-043248.nc
# ../training_data_v2\outputs_0xSA_SO2.nc
# ../logs/lr_1lin/0xSA SO2 only\posterior_predictY_0xSA_SO2_20250325-071124.nc
# ../training_data_v2\outputs_10xEU_BC.nc
# ../logs/lr_1lin/10xEU BC only\posterior_predictY_10xEU_BC_20250325-015301.nc
# ../training_data_v2\outputs_10xNA_BC.nc
# ../logs/lr_1lin/10xNA BC only\posterior_predictY_10xNA_BC_20250325-045537.nc
# ../training_data_v2\outputs_10xSA_BC.nc
# ../logs/lr_1lin/10xSA BC only\posterior_predictY_10xSA_BC_20250325-073416.nc
# ../training_data_v2\outputs_10xSA_SO2.nc
# ../logs/lr_1lin/10xSA SO2 only\posterior_predictY_10xSA_SO2_20250325-075655.nc
# ../training_data_v2\outputs_5xEA_BC.nc
# ../logs/lr_1lin/5xEA BC only\posterior_predictY_5xEA_BC_20250325-004455.nc
# ../training_data_v2\outputs_5xEA_SO2.nc
# ../logs/lr_1lin/5xEA SO2 only\posterior_predictY_5xEA_SO2_20250325-010731.nc
# ../training_data_v2\outputs_5xNA_SO2.nc
# ../logs/lr_1lin/5xNA SO2 only\posterior_predictY_5xNA_SO2_20250325-051808.nc
# ../training_data_v2\outputs_7xEU_SO2.nc
# ../logs/lr_1lin/7xEU SO2 only\posterior_predictY_7xEU_SO2_20250325-021538.nc
# ../training_data_v2\outputs_AeroGP1.nc
# ../logs/lr_1lin/AeroGP1\posterior_predictY_AeroGP1_20250324-233720.nc
# ../training_data_v2\outputs_AeroGP2.nc
# ../logs/lr_1lin/AeroGP2\posterior_predictY_AeroGP2_20250324-235919.nc
# ../training_data_v2\outputs_global_anthro.nc
# ../logs/lr_1lin/Global Anthro Removal\posterior_predictY_global_anthro_20250325-023824.nc
# ../training_data_v2\outputs_global_BC.nc
# ../logs/lr_1lin/Global BC removal only\posterior_predictY_global_BC_20250325-030055.nc
# ../training_data_v2\outputs_global_OC.nc
# ../logs/lr_1lin/Global OC removal only\posterior_predictY_global_OC_20250325-032344.nc
# ../training_data_v2\outputs_global_SO2.nc
# ../logs/lr_1lin/Global SO2 removal only\posterior_predictY_global_SO2_20250325-034633.nc
# ../training_data_v2\outputs_hist-aer.nc
# ../logs/lr_1lin/hist-aer\posterior_predictY_hist-aer_20250324-193235.nc
# ../training_data_v2\outputs_ramip_af.nc
# ../logs/lr_1lin/RAMIP AF\posterior_predictY_ramip_af_20250325-054052.nc
# ../training_data_v2\outputs_ramip_ea.nc
# ../logs/lr_1lin/RAMIP EA\posterior_predictY_ramip_ea_20250324-205726.nc
# ../training_data_v2\outputs_ramip_nae.nc
# ../logs/lr_1lin/RAMIP NAE\posterior_predictY_ramip_nae_20250325-060325.nc
# ../training_data_v2\outputs_ramip_sa.nc
# ../logs/lr_1lin/RAMIP SA\posterior_predictY_ramip_sa_20250325-062612.nc
# ../training_data_v2\outputs_ramip_t1.nc
# ../logs/lr_1lin/RAMIP T1\posterior_predictY_ramip_t1_20250324-200737.nc
# ../training_data_v2\outputs_ssp245-aer.nc
# ../logs/lr_1lin/ssp245-aer\posterior_predictY_ssp245-aer_20250325-082037.nc
# ../training_data_v2\outputs_ssp370-NTCF.nc
# ../logs/lr_1lin/ssp370-lowNTCF\posterior_predictY_ssp370-NTCF_20250325-084305.nc

# %%
exp_id
# Out:
# 'ssp370-lowNTCF'

# %%
# some edits for display

#fix some experiment names for plotting table:
df.replace('ssp245-aer', 'DAMIP ssp245-aer', inplace=True)
df.replace('hist-aer', 'DAMIP hist-aer', inplace=True)

df = df.infer_objects().astype(np.float64, errors='ignore')

#add column for NorESM version:
df['NorESM version'] = np.where(df['Experiment'].str.contains('RAMIP') | df['Experiment'].str.contains('DAMIP') | df['Experiment'].str.contains('AeroGP') | df['Experiment'].str.contains('ssp370'), 'NorESM2', 'NorESM1')

# %%
df.sort_values(by='NRMSE').style\
    .background_gradient()\
    .format(precision=2)\
    .hide()
# Out:
# <style type="text/css">
# #T_cb1dc_row0_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_cb1dc_row0_col2, #T_cb1dc_row1_col5, #T_cb1dc_row1_col6, #T_cb1dc_row18_col3, #T_cb1dc_row24_col1, #T_cb1dc_row25_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cb1dc_row0_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_cb1dc_row0_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_cb1dc_row0_col5 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_cb1dc_row0_col6 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_cb1dc_row1_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_cb1dc_row1_col2, #T_cb1dc_row14_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_cb1dc_row1_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_cb1dc_row1_col4, #T_cb1dc_row3_col1, #T_cb1dc_row3_col3, #T_cb1dc_row3_col5, #T_cb1dc_row3_col6, #T_cb1dc_row25_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cb1dc_row2_col1, #T_cb1dc_row4_col4, #T_cb1dc_row18_col6 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_cb1dc_row2_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_cb1dc_row2_col3 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_cb1dc_row2_col4 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_cb1dc_row2_col5, #T_cb1dc_row2_col6, #T_cb1dc_row13_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_cb1dc_row3_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_cb1dc_row3_col4, #T_cb1dc_row19_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_cb1dc_row4_col1, #T_cb1dc_row4_col5 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_cb1dc_row4_col2, #T_cb1dc_row20_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_cb1dc_row4_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_cb1dc_row4_col6 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_cb1dc_row5_col1, #T_cb1dc_row24_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_cb1dc_row5_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_cb1dc_row5_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_cb1dc_row5_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_cb1dc_row5_col5 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_cb1dc_row5_col6 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_cb1dc_row6_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_cb1dc_row6_col2, #T_cb1dc_row15_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_cb1dc_row6_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_cb1dc_row6_col4, #T_cb1dc_row23_col5 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_cb1dc_row6_col5 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_cb1dc_row6_col6, #T_cb1dc_row7_col5 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_cb1dc_row7_col1 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_cb1dc_row7_col2, #T_cb1dc_row8_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_cb1dc_row7_col3, #T_cb1dc_row13_col2, #T_cb1dc_row22_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_cb1dc_row7_col4, #T_cb1dc_row20_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_cb1dc_row7_col6 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_cb1dc_row8_col1, #T_cb1dc_row22_col6 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_cb1dc_row8_col3, #T_cb1dc_row9_col2, #T_cb1dc_row14_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_cb1dc_row8_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_cb1dc_row8_col5, #T_cb1dc_row10_col4, #T_cb1dc_row17_col6 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_cb1dc_row8_col6 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_cb1dc_row9_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_cb1dc_row9_col3, #T_cb1dc_row17_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_cb1dc_row9_col4, #T_cb1dc_row22_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_cb1dc_row9_col5, #T_cb1dc_row19_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_cb1dc_row9_col6 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_cb1dc_row10_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_cb1dc_row10_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_cb1dc_row10_col3, #T_cb1dc_row14_col2, #T_cb1dc_row15_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_cb1dc_row10_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_cb1dc_row10_col6 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_cb1dc_row11_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_cb1dc_row11_col2, #T_cb1dc_row12_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_cb1dc_row11_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_cb1dc_row11_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_cb1dc_row11_col5 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_cb1dc_row11_col6 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_cb1dc_row12_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_cb1dc_row12_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_cb1dc_row12_col4 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_cb1dc_row12_col5 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_cb1dc_row12_col6, #T_cb1dc_row13_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_cb1dc_row13_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_cb1dc_row13_col5, #T_cb1dc_row15_col5, #T_cb1dc_row17_col5 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_cb1dc_row13_col6, #T_cb1dc_row24_col6 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_cb1dc_row14_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_cb1dc_row14_col5 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_cb1dc_row14_col6 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_cb1dc_row15_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_cb1dc_row15_col4 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_cb1dc_row15_col6 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_cb1dc_row16_col1, #T_cb1dc_row16_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_cb1dc_row16_col2 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_cb1dc_row16_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_cb1dc_row16_col5, #T_cb1dc_row22_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_cb1dc_row16_col6 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_cb1dc_row17_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_cb1dc_row17_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_cb1dc_row17_col4, #T_cb1dc_row19_col5 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_cb1dc_row18_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_cb1dc_row18_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_cb1dc_row18_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_cb1dc_row18_col5 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_cb1dc_row19_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_cb1dc_row19_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_cb1dc_row19_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_cb1dc_row20_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_cb1dc_row20_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_cb1dc_row20_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_cb1dc_row20_col6 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_cb1dc_row21_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_cb1dc_row21_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_cb1dc_row21_col3 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_cb1dc_row21_col4 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_cb1dc_row21_col5 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_cb1dc_row21_col6 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_cb1dc_row22_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_cb1dc_row22_col4, #T_cb1dc_row25_col5 {
#   background-color: #2d8abd;
#   color: #f

# %%
#save to csv:
df.to_csv('figure2_stats_lr.csv', index=False)

# %%
#save to png:
#dfi.export(df_styled,'Evaluation_stats_table.png')
